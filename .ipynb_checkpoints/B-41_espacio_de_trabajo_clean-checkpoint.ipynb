# %% [markdown]
# # B-41 Espacio de trabajo
#
# Notebook para pruebas legacy/intermedias separadas del flujo principal.

# %% [markdown]
# ## Legacy section disabled
#
# Usa este notebook para experimentar sin modificar el flujo principal de generación sintética.

# %%
# Espacio libre para pruebas.
