# %% [markdown]
# # B-41 Espacio de trabajo
#
# Este notebook contiene la parte legacy y pruebas intermedias que arrancaban desde la sección marcada como `# Legacy section disabled`.

# %% [markdown]
# ## Legacy section disabled
#
# Usa este espacio para mover/recuperar cualquier bloque legacy que quieras seguir conservando sin mezclarlo con el flujo principal.

# %%
# Espacio libre para pruebas legacy.
